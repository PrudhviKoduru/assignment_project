# %%
metrics = df.groupby("path")[["cost_usd", "energy_j"]].mean().reset_index()

fig, ax1 = plt.subplots(figsize=(8,5))
sns.barplot(data=metrics, x="path", y="cost_usd", color="skyblue", ax=ax1, label="Cost (USD)")
ax2 = ax1.twinx()
sns.lineplot(data=metrics, x="path", y="energy_j", color="tomato", marker="o", ax=ax2, label="Energy (J)")

ax1.set_xlabel("Layer")
ax1.set_ylabel("Average Cost (USD)")
ax2.set_ylabel("Average Energy (Joules)")
plt.title("Average Cost and Energy by Processing Layer")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read data
df = pd.read_csv("rc_results.csv")

# Style
sns.set(style="whitegrid", context="talk", palette="deep")

print(f"Loaded {len(df):,} IoT events")
# Out:
# Loaded 10,000 IoT events
